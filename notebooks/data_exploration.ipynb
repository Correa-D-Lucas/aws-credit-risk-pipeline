# %%
import pandas as pd
import os
from pathlib import Path

# %%
df = pd.read_csv("/app/data/raw/application_train.csv", header=0)
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# see all the columns
df.head(1).to_json("readable_application_data.json", orient="records", indent=4, mode="w")
